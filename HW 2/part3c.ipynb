# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torch import nn
from tqdm import tqdm_notebook as tqdm
from tqdm import tqdm as tqdm_

# %%
# set device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %%
# define dataset

class SensorlessDataset(Dataset):
  
  def __init__(self, dataframe):
    self.dataset = dataframe.values
    self.dataset = torch.tensor(self.dataset)
    
  def __len__(self):
    return len(self.dataset)
  
  def __getitem__(self, idx):
    return self.dataset[idx, :-1].float(), self.dataset[idx, -1].long()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# load data
data_filename = 'gdrive/My Drive/Colab Notebooks/OnlineNewsPopularity/HW2/data/Sensorless_drive_diagnosis.txt'
df = pd.read_csv(data_filename, delimiter=' ', header=None)

# %%
# shift class by 1
df['class'] = df[48] - 1

# print number of samples in each class
print('number of samples in each class:\n\n', df['class'].value_counts())

# drop column in -2
df.drop(df.columns[-2], axis=1, inplace=True)
# Out:
# number of samples in each class:
#
#  10    5319
# 9     5319
# 8     5319
# 7     5319
# 6     5319
# 5     5319
# 4     5319
# 3     5319
# 2     5319
# 1     5319
# 0     5319
# Name: class, dtype: int64

# %%
# shuffle
df = df.sample(frac=1, random_state=123).reset_index(drop=True)

# %%
# define model

class Model(nn.Module):
  def __init__(self, num_features, num_classes):
    super(Model, self).__init__()
    
    self.fc1 = nn.Linear(num_features, 64)
    self.relu1 = nn.ReLU()
    self.fc2 = nn.Linear(64, 128)
    self.relu2 = nn.ReLU()
    self.fc3 = nn.Linear(128, 256)
    self.relu3 = nn.ReLU()
    self.fc4 = nn.Linear(256, 256)
    self.relu4 = nn.ReLU()
    self.fc5 = nn.Linear(256, 128)
    self.relu5 = nn.ReLU()
    self.fc6 = nn.Linear(128, 64)
    self.relu6 = nn.ReLU()
    self.fc7 = nn.Linear(64, num_classes)
    
  def forward(self, x):
    x = self.relu1(self.fc1(x))
    x = self.relu2(self.fc2(x))
    x = self.relu3(self.fc3(x))
    x = self.relu4(self.fc4(x))
    x = self.relu5(self.fc5(x))
    x = self.relu6(self.fc6(x))
    x = self.fc7(x)
    return x

# %%
# define train method

def train(data_loader, model, optimizer, criterion, curr_epoch, tot_epochs, device):
  
  # set model to training mode
  model.train()
  
  tot_train_loss = 0.0
  
  train_meter = tqdm(
      data_loader, unit=' batches',
      desc=f'[Epoch {curr_epoch}/{tot_epochs}]',
      leave=False
  )
  
  for batch_idx, (sample, label) in enumerate(train_meter):
    
    # transfer to device
    sample, label = sample.to(device), label.to(device)
    
    # zero out gradients
    optimizer.zero_grad()
    
    # forward pass
    out = model(sample)
    
    # compute loss
    loss = criterion(out, label)
    
    # backward
    loss.backward()
    
    # optimizer step
    optimizer.step()
    
    # update tqdm meter
    train_meter.set_postfix(train_loss=f'{loss.item():0.4f}')
    train_meter.update()
    
    # add to total train loss
    tot_train_loss = tot_train_loss + loss.item()
    
  av_train_loss = tot_train_loss / (batch_idx + 1)
  return av_train_loss

# %%
# define validation method

def validate(data_loader, model, criterion, device):
  
  # set model to eval mode
  model.eval()
  
  tot_val_loss = 0.0
  corrects = 0
  total = 0
  
  val_meter = tqdm(
      data_loader, unit=' batches',
      desc='val',
      leave=False
  )
  
  with torch.no_grad():
    for batch_idx, (sample, label) in enumerate(val_meter):

      # transfer to device
      sample, label = sample.to(device), label.to(device)

      # forward pass
      out = model(sample)

      # compute loss
      loss = criterion(out, label)
      
      # compute the prediction
      max_value, pred = torch.max(out, dim=-1)
      
      # compute number of correct predictions
      corrects += (pred == label).sum().item()

      # update total samples
      total = total + len(label)

      # update tqdm meter
      val_meter.set_postfix(val_loss=f'{loss.item():0.4f}')
      val_meter.update()

      # add to total val loss
      tot_val_loss = tot_val_loss + loss.item()

  av_val_loss = tot_val_loss / (batch_idx + 1)
  accuracy = corrects / total
  return av_val_loss, accuracy

# %%
# specify learning rate
learning_rate = 0.01

# specify criterion
criterion = nn.CrossEntropyLoss()

# %%
all_train_losses = []
all_val_losses = []
all_accs = []
all_best_accs = []
for cv_idx, cv in enumerate([4000, 5000, 7000, 8000, 9000]):

  print(89 * '-')
  print(f'Training fold {cv_idx + 1}')
  print(89 * '-')

  # split into train, val and test
  df_train, df_val, df_test = df.loc[cv:], df.loc[cv - 1000: cv - 1], df.loc[:999]

  # create datasets
  train_dataset = SensorlessDataset(df_train)
  val_dataset = SensorlessDataset(df_val)
  test_dataset = SensorlessDataset(df_test)

  # create data loaders
  train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
  val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)
  test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

  # create model object
  model = Model(num_features=48, num_classes=11)

  # transfer model to device
  model = model.to(device)

  # create optimizer
  optimizer = torch.optim.Adam(
      filter(lambda param: param.requires_grad, model.parameters()),
      lr=learning_rate
  )

  # specify max number of epochs
  num_epochs = 30

  train_losses, val_losses, accs = [], [], []

  min_val_loss = np.inf
  best_acc = -1
  for epoch in range(1, num_epochs + 1):
    train_loss = train(train_loader, model, optimizer, criterion, epoch, num_epochs, device)
    val_loss, accuracy = validate(val_loader, model, criterion, device)

    if val_loss <= min_val_loss:
      min_val_loss = val_loss
      best_acc = accuracy
    
    # check for early stopping
    if all(val_loss > loss for loss in val_losses[-3:]) and len(val_losses) > 2: 
      print('stopping early')
      break
    
    # save losses
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    accs.append(accuracy)
    
    # print losses and accuracies
    tqdm_.write(f'[Epoch {epoch}/{num_epochs}] train loss: {train_loss:0.4f}, val loss: {val_loss:0.4f}, accuracy: {accuracy * 100:0.2f} %')
  
  all_train_losses.append(train_losses)
  all_val_losses.append(val_losses)
  all_accs.append(accs)
  all_best_accs.append(best_acc)
# Out:
# -----------------------------------------------------------------------------------------
# Training fold 1
# -----------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='[Epoch 1/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 1/30] train loss: 2.6114, val loss: 0.8248, accuracy: 61.20 %
# HBox(children=(IntProgress(value=0, description='[Epoch 2/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 2/30] train loss: 1.0972, val loss: 0.8641, accuracy: 58.10 %
# HBox(children=(IntProgress(value=0, description='[Epoch 3/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 3/30] train loss: 1.2556, val loss: 0.7728, accuracy: 65.30 %
# HBox(children=(IntProgress(value=0, description='[Epoch 4/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 4/30] train loss: 1.0180, val loss: 0.6204, accuracy: 69.20 %
# HBox(children=(IntProgress(value=0, description='[Epoch 5/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 5/30] train loss: 0.6561, val loss: 0.4383, accuracy: 82.60 %
# HBox(children=(IntProgress(value=0, description='[Epoch 6/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 6/30] train loss: 0.4295, val loss: 0.4764, accuracy: 81.90 %
# HBox(children=(IntProgress(value=0, description='[Epoch 7/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 7/30] train loss: 0.4255, val loss: 0.3461, accuracy: 85.50 %
# HBox(children=(IntProgress(value=0, description='[Epoch 8/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 8/30] train loss: 0.4038, val loss: 0.3130, accuracy: 87.70 %
# HBox(children=(IntProgress(value=0, description='[Epoch 9/30]', max=852, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 9/30] train loss: 0.3837, val loss: 0.3449, accuracy: 84.00 %
# HBox(children=(IntProgress(value=0, description='[Epoch 10/30]', max=852, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# stopping early
# -----------------------------------------------------------------------------------------
# Training fold 2
# -----------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='[Epoch 1/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 1/30] train loss: 2.3004, val loss: 1.0296, accuracy: 52.40 %
# HBox(children=(IntProgress(value=0, description='[Epoch 2/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 2/30] train loss: 1.0650, val loss: 0.9841, accuracy: 54.80 %
# HBox(children=(IntProgress(value=0, description='[Epoch 3/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 3/30] train loss: 0.8212, val loss: 0.8411, accuracy: 59.40 %
# HBox(children=(IntProgress(value=0, description='[Epoch 4/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 4/30] train loss: 0.7967, val loss: 0.8757, accuracy: 59.90 %
# HBox(children=(IntProgress(value=0, description='[Epoch 5/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 5/30] train loss: 0.7845, val loss: 0.8191, accuracy: 61.40 %
# HBox(children=(IntProgress(value=0, description='[Epoch 6/30]', max=837, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# stopping early
# -----------------------------------------------------------------------------------------
# Training fold 3
# -----------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='[Epoch 1/30]', max=805, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 1/30] train loss: 2.4002, val loss: 2.4001, accuracy: 8.00 %
# HBox(children=(IntProgress(value=0, description='[Epoch 2/30]', max=805, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 2/30] train loss: 2.3992, val loss: 2.3979, accuracy: 9.20 %
# HBox(children=(IntProgress(value=0, description='[Epoch 3/30]', max=805, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 3/30] train loss: 2.3990, val loss: 2.3986, accuracy: 8.70 %
# HBox(children=(IntProgress(value=0, description='[Epoch 4/30]', max=805, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 4/30] train loss: 2.3990, val loss: 2.3974, accuracy: 10.10 %
# HBox(children=(IntProgress(value=0, description='[Epoch 5/30]', max=805, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# stopping early
# -----------------------------------------------------------------------------------------
# Training fold 4
# -----------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='[Epoch 1/30]', max=790, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 1/30] train loss: 2.3996, val loss: 2.3986, accuracy: 8.30 %
# HBox(children=(IntProgress(value=0, description='[Epoch 2/30]', max=790, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 2/30] train loss: 2.3990, val loss: 2.4008, accuracy: 8.20 %
# HBox(children=(IntProgress(value=0, description='[Epoch 3/30]', max=790, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 3/30] train loss: 2.3988, val loss: 2.4002, accuracy: 7.50 %
# HBox(children=(IntProgress(value=0, description='[Epoch 4/30]', max=790, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 4/30] train loss: 2.3988, val loss: 2.3983, accuracy: 10.30 %
# HBox(children=(IntProgress(value=0, description='[Epoch 5/30]', max=790, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# stopping early
# -----------------------------------------------------------------------------------------
# Training fold 5
# -----------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='[Epoch 1/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 1/30] train loss: 1.7273, val loss: 0.9025, accuracy: 58.00 %
# HBox(children=(IntProgress(value=0, description='[Epoch 2/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 2/30] train loss: 0.9700, val loss: 3.6163, accuracy: 57.90 %
# HBox(children=(IntProgress(value=0, description='[Epoch 3/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 3/30] train loss: 0.8304, val loss: 0.7651, accuracy: 60.60 %
# HBox(children=(IntProgress(value=0, description='[Epoch 4/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 4/30] train loss: 0.7911, val loss: 0.7522, accuracy: 65.60 %
# HBox(children=(IntProgress(value=0, description='[Epoch 5/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 5/30] train loss: 0.7669, val loss: 1.4454, accuracy: 70.30 %
# HBox(children=(IntProgress(value=0, description='[Epoch 6/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 6/30] train loss: 0.5028, val loss: 0.6772, accuracy: 71.70 %
# HBox(children=(IntProgress(value=0, description='[Epoch 7/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 7/30] train loss: 0.4517, val loss: 0.5341, accuracy: 75.50 %
# HBox(children=(IntProgress(value=0, description='[Epoch 8/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 8/30] train loss: 0.4308, val loss: 0.4307, accuracy: 83.20 %
# HBox(children=(IntProgress(value=0, description='[Epoch 9/30]', max=774, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 9/30] train loss: 0.3962, val loss: 0.3581, accuracy: 85.00 %
# HBox(children=(IntProgress(value=0, description='[Epoch 10/30]', max=774, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# [Epoch 10/30] train loss: 0.4113, val loss: 0.3886, accuracy: 83.30 %
# HBox(children=(IntProgress(value=0, description='[Epoch 11/30]', max=774, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='val', max=16, style=ProgressStyle(description_width='initial'…
# stopping early

# %%
# plot losses
for cv_idx in range(5):
  train_losses = all_train_losses[cv_idx]
  val_losses = all_val_losses[cv_idx]
  assert len(train_losses) == len(val_losses), 'number of training epochs and validation losses differ'
  plt.plot(range(1, len(train_losses) + 1), train_losses, label='train', c='blue')
  plt.plot(range(1, len(val_losses) + 1), val_losses, label='val', c='red')
  
  plt.xlabel('epochs', fontsize=14)
  plt.ylabel('loss', fontsize=14)
  plt.title(f'Fold {cv_idx + 1}', fontsize=20)
  plt.xticks(range(1, len(train_losses) + 1))
  plt.legend()
  plt.show()

# %%
# plot accuracies
for cv_idx in range(5):
  accs = all_accs[cv_idx]
  plt.plot(range(1, len(accs) + 1), accs, label='val', c='red')
  plt.legend()
  plt.xlabel('epochs', fontsize=14)
  plt.ylabel('accuracy', fontsize=14)
  plt.title(f'Fold {cv_idx + 1}', fontsize=20)
  plt.xticks(range(1, len(accs) + 1))
  plt.show()
