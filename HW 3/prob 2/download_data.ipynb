# %%
import os
import sys

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# kaggle credentials
kaggle_username = "<KAGGLE USERNAME>"
kaggle_key = "<KAGGLE KEY>"
os.environ['KAGGLE_USERNAME'] = kaggle_username
os.environ['KAGGLE_KEY'] = kaggle_key

# create kaggle.json file
# !echo "{"username":"<KAGGLE USERNAME>","key":"<KAGGLE KEY>"}" > /root/.kaggle/kaggle.json

# %%
# data directory
data_dir = "gdrive/My Drive/Colab Notebooks/oregon wildlife/data"
os.makedirs(data_dir, exist_ok=True)

# %%
# download kaggle dataset
# !kaggle datasets download -d iarunava/happy-house-dataset
# !kaggle datasets download -d virtualdvid/oregon-wildlife -p gdrive/My\ Drive/Colab\ Notebooks/oregon\ wildlife/data
# Out:
# ...
# 100% 4.54G/4.55G [02:08<00:00, 37.1MB/s]
# 100% 4.55G/4.55G [02:08<00:00, 37.9MB/s]

# %%
# unzip and extract
import zipfile

zipped_filename = 'oregon-wildlife.zip'
with zipfile.ZipFile(os.path.join(data_dir, zipped_filename), 'r') as zip_ref:
    zip_ref.extractall(data_dir)

# %%
# update data directory path to extracted path
data_dir = os.path.join("gdrive/My Drive/Colab Notebooks/oregon wildlife/data", 
                        "oregon_wildlife", "oregon_wildlife")
# print folders in data directory
print(os.listdir(data_dir))
# Out:
# ['bald_eagle', 'black_bear', 'bobcat', 'canada_lynx', 'columbian_black-tailed_deer', 'cougar', 'coyote', 'deer', 'elk', 'gray_fox', 'gray_wolf', 'mountain_beaver', 'nutria', 'raccoon', 'raven', 'red_fox', 'ringtail', 'sea_lions', 'seals', 'virginia_opossum']
